# %% [markdown]
# # Operaciones Básicas con Python en Jupyter

# %% [markdown]
# Operaciones *Aritméticas*

# %% [markdown]
# - Suma

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# - Resta

# %%
100 - 9
# Out:
# 91

# %% [markdown]
# - Multiplicación

# %%
1000 * 2
# Out:
# 2000

# %% [markdown]
# - División

# %%
50 / 10
# Out:
# 5.0

# %% [markdown]
# **Función de Python**

# %%
def f(x):
    return 2*x
y = f(3)
print(y)
# Out:
# 6

# %% [markdown]
# # Subo una imagen con Matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Ruta de la imagen
ruta = r"C:\Users\X\Desktop\Machine Learning\Sprint 0\HelloWorld.jpg"

# Cargar y mostrar la imagen
img = mpimg.imread(ruta)
plt.imshow(img)
plt.axis('off')  # Ocultar ejes (opcional)
plt.show()
